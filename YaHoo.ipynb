a data-ylk="sec:eyebrow;subsec:property;" href="https://tw.bid.yahoo.com/?co_servername=aUH&amp;co_servername2=aUH">拍賣</a>, <a class="NoTextDecoration Pos-r Z-1 yucs-leavable rapidnofollow" data-plugin="toggle" data-toggle='[{"target":".MoreDropDown-Box","click":{"toggle":{"classnames":"Hidden"}}}, {"target-ancestor":".MoreDropDown","click":{"toggle":{"classnames":"MoreDropDown-on"}}}]' href="" id="yucs-more-link" role="button">
# <i class="Lh-1 D-ib">更多</i>
# <i class="Icon Fz-m Va-m Lh-1 W-a Mstart-2" style="*vertical-align: bottom;"></i>
# </a>, <a class="D-b" href="https://tw.answers.yahoo.com/">知識+</a>, <a class="D-b" href="https://tw.dictionary.search.yahoo.com/">字典</a>, <a class="D-b" href="https://tw.money.yahoo.com/">理財</a>, <a class="D-b" href="https://autos.yahoo.com.tw/">汽車機車</a>, <a class="D-b" href="https://movies.yahoo.com.tw/">電影</a>, <a class="D-b" href="https://games.yahoo.com.tw/">遊戲</a>, <a class="D-b" href="https://travel.yahoo.com.tw/">旅遊</a>, <a class="D-b" href="https://house.yahoo.com.tw/">房地產</a>, <a class="D-b" href="https://style.yahoo.com.tw/">時尚美妝</a>, <a class="D-b" href="https://tw.news.yahoo.com/technology">3C科技</a>, <a class="D-b" href="https://tw.buy.yahoo.com/bestbuy?co_servername=yUHDab">每日好康</a>, <a class="C-w Cur-p promotion-text" data-ylk="rspns:nav;t1:a3;t2:uh;t3:ct;sec:eyebrow;subsec:hpset;slk:hpset;elm:btn;elmt:ct;itc:1;" href="https://tw.help.yahoo.com/kb/SLN2208.html" target="_blank">設定 Yahoo 為首頁</a>, <a class="Mt-2 D-b Ta-end NoTextDecoration rapidnofollow" data-plugin="tooltip" data-tooltip='{"default":{"toggle":{"position":"bfr","width":"610px","id":"intl-tooltip", "parent":"#yucs-top-intls"}}}' data-trigger="click" data-ylk="sec:eyebrow;subsec:lang;slk:select;" href="#0" onclick="arguments[0].preventDefault();">
# <i class="Va-m D-ib intl-flag flag-tw"></i>
# <i class="Icon Fz-m Va-m Lh-1 W-a C-1"></i>
# </a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Australia;" href="https://au.yahoo.com/?p=dnr" target="_top">Australia</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:香港;" href="https://hk.yahoo.com/?p=dnr" target="_top">香港</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:India;" href="https://in.yahoo.com/" target="_top">India</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Indonesia;" href="https://id.yahoo.com/" target="_top">Indonesia</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:New Zealand;" href="https://nz.yahoo.com/?p=dnr" target="_top">New Zealand</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Philippines;" href="https://ph.yahoo.com/" target="_top">Philippines</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Singapore;" href="https://sg.yahoo.com/" target="_top">Singapore</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Malaysia;" href="https://malaysia.yahoo.com/" target="_top">Malaysia</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Việt Nam;" href="https://vn.yahoo.com/" target="_top">Việt Nam</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:日本;" href="http://www.yahoo.co.jp/" target="_top">日本</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:België (nl);" href="https://be.yahoo.com/" target="_top">België (nl)</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Belgique (fr);" href="https://fr-be.yahoo.com/" target="_top">Belgique (fr)</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Deutschland;" href="https://de.yahoo.com/" target="_top">Deutschland</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:France;" href="https://fr.yahoo.com/" target="_top">France</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Ελλάδα;" href="https://gr.yahoo.com/" target="_top">Ελλάδα</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Ireland;" href="https://ie.yahoo.com/" target="_top">Ireland</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Italia;" href="https://it.yahoo.com/" target="_top">Italia</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:România;" href="https://ro.yahoo.com/" target="_top">România</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:España;" href="https://es.yahoo.com/" target="_top">España</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Sverige;" href="https://se.yahoo.com/" target="_top">Sverige</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:United Kingdom;" href="https://uk.yahoo.com/" target="_top">United Kingdom</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Maktoob (eng);" href="https://en-maktoob.yahoo.com/" target="_top">Maktoob (eng)</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:مكتوب (العربية);" href="https://maktoob.yahoo.com/" target="_top">مكتوب (العربية)</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:South Africa;" href="https://za.yahoo.com/" target="_top">South Africa</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Canada (eng);" href="https://ca.yahoo.com/" target="_top">Canada (eng)</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Canada (fr);" href="https://qc.yahoo.com/" target="_top">Canada (fr)</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:México;" href="https://mx.yahoo.com/" target="_top">México</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:US (eng);" href="https://us.yahoo.com" target="_top">US (eng)</a>, <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Estados Unidos (es);" href="https://espanol.yahoo.com/" target=" ...
# <img alt="" class="D-ib Lh-1 Va-t Pend-16 Weather-Simple-Image" height="27" src="https://s.yimg.com/f/i/tw/hp/hkhr14_png24a/scattered_showers_day_night.png" width="27"/>
# <b class="Pos-a T-0 End-0">24°</b>
# </a>, <a aria-haspopup="true" class="yucs-trigger D-ib MouseOver NoTextDecoration W-100" data-plugin="tooltip" data-tooltip='{"target-child":".Icon","click":{"toggle":{"position":"b","minWidth":"170px","id":"UHLogin","parent":"tabbar-signin"}},"mouseenter":{"show":{"mouseover":true,"position":"b","minWidth":"170px","id":"UHLogin"}},"mouseleave":{"hide":{"id":"UHLogin"}}}' data-trigger="mouseenter mouseleave click" data-ylk="subsec:login;" href="https://login.yahoo.com/config/login?.src=twfp&amp;.lang=zh-Hant-TW&amp;.intl=tw&amp;.done=https://tw.yahoo.com/" id="uh-profile" role="button">
# <i class="t-ico Icon Lh-1 C-darkGrey Zoom-1 Va-t portrait-light"></i>
# <b class="t-txt MouseOver-TextDecoration Va-b Lh-12 D-ib">登入</b>
# </a>, <a class="D-b NoTextDecoration Va-t Trigger Btn-y W-100" href="https://login.yahoo.com/config/login?.src=twfp&amp;.lang=zh-Hant-TW&amp;.intl=tw&amp;.done=https://tw.yahoo.com/">
# <i class="Va-m Icon Fz-xs login-btn-yahoo"></i>
# <b class="Va-m Fz-xs Px-4">Yahoo奇摩帳號登入</b>
# </a>, <a class="sign-up Ta-start D-i" href="https://tw.edit.yahoo.com/registration?.intl=tw&amp;.src=fpctx&amp;.done=https://tw.yahoo.com/">請註冊</a>, <a aria-haspopup="true" class="yucs-trigger D-ib MouseOver NoTextDecoration" data-plugin="tooltip" data-tooltip='{"target-child":".","click":{"toggle":{"position":"b","minWidth":"170px","id":"","parent":"tabbar-mail"}},"mouseenter":{"show":{"mouseover":true,"position":"b","minWidth":"170px","id":""}},"mouseleave":{"hide":{"id":""}}}' data-trigger="mouseenter mouseleave click" data-ylk="subsec:mail;" href="https://mail.yahoo.com/?.intl=tw&amp;.lang=zh-Hant-TW" role="button">
# <b class="mail-badge C-w D-n" data-mc-crumb="" login-id=""></b>
# <i class="Mail-Icon t-ico Icon Lh-1 C-darkGrey Zoom-1 Va-t"></i>
# <b class="t-txt Va-b MouseOver-TextDecoration Lh-12 Mstart-6 D-ib" title="信箱">信箱</b>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.news.yahoo.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">新聞</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.stock.yahoo.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">股市</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.money.yahoo.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">理財</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.sports.yahoo.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">運動</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.sports.yahoo.com/cpbl/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="color:#EF4E5E;">中職</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.news.yahoo.com/entertainment">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">名人娛樂</span>
# </a>, <a class="drag-item D-b Td-n" href="https://movies.yahoo.com.tw/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">電影</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.tv.yahoo.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="line-height:1.1;font-size:14px;">Yahoo TV</span>
# </a>, <a class="drag-item D-b Td-n" href="https://games.yahoo.com.tw/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">遊戲</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.esports.yahoo.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">電競</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.tv.yahoo.com/animation/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">動漫</span>
# </a>, <a class="drag-item D-b Td-n" href="https://twyahoo.buyee.jp/cobrand?utm_source=twy&amp;utm_medium=twy_toppage_pc&amp;rc=twy_toppage_pc&amp;mrc1=twy&amp;mrc2=twy_toppage_pc&amp;mrc3=link">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">日本代購</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.dictionary.yahoo.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">字典</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.answers.yahoo.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">知識+</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.news.yahoo.com/technology/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">3C科技</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.mail.yahoo.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">信箱</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.news.yahoo.com/weather/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">氣象</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.campaign.money.yahoo.com/atm/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">ATM</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.charity.yahoo.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">公益</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.ysm.emarketing.yahoo.com/soeasy/index.php">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">找店+</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.bid.yahoo.com/?co_servername=aME&amp;co_servername2=aME">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">拍賣</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.buy.yahoo.com/?co_servername=sME&amp;c2=sME">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="color:#EF4E5E;">購物中心</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.mall.yahoo.com/?_co=pME&amp;_co2=pME">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">超級商城</span>
# </a>, <a class="drag-item D-b Td-n" href="https://yahoo.buy123.com.tw/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">生活團購</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.buy.yahoo.com/bestbuy?co_servername=yTDab">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">每日好康</span>
# </a>, <a class="drag-item D-b Td-n" href="https://autos.yahoo.com.tw/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">汽車機車</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.usedcar.yahoo.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">中古車</span>
# </a>, <a class="drag-item D-b Td-n" href="https://yahoo.ebo.tmnewa.com.tw/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">保險</span>
# </a>, <a class="drag-item D-b Td-n" href="https://style.yahoo.com.tw/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">時尚美妝</span>
# </a>, <a class="drag-item D-b Td-n" href="https://house.yahoo.com.tw/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">房地產</span>
# </a>, <a class="drag-item D-b Td-n" href="https://travel.yahoo.com.tw/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">旅遊</span>
# </a>, <a class="drag-item D-b Td-n" href="https://yahoo.everydayhealth.com.tw">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">健康</span>
# </a>, <a class="drag-item D-b Td-n" href="https://yahoo.click108.com.tw/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">星座算命</span>
# </a>, <a class="drag-item D-b Td-n" href="http://yahoomode.tumblr.com/yahooapp">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">APP下載</span>
# </a>, <a class="drag-item D-b Td-n" href="http://twbuyyahoo.tumblr.com/joinus">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">網路開店</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.emarketing.yahoo.com/ysmacq/index.html?_ycmp=fp_fix">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">買關鍵字</span>
# </a>, <a class="drag-item D-b Td-n" href="http://yahoo-emarketing.tumblr.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">網路行銷</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.cards.yahoo.com/">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="">聯名卡</span>
# </a>, <a class="drag-item D-b Td-n" href="https://tw.bid.yahoo.com/help/new_auc/tns/2sv/index.html">
# <span class="Cur-p D-ib Py-8 C-blue MouseOver-TextDecoration" style="
# <p class="LineClamp Whs-n Fw-b Mt-2 Mb-6 Lh-14 headline">美國Husk’s ware稻殼天然無毒環保兒童餐具經典人偶款-桃紅色</p>
# </a>, <a class="D-n" data-ylk="slk:AdCheck" href="https://global.adserver.yahoo.com/a?f=794028844&amp;p=tw_kimo&amp;l=Z&amp;c=h&amp;bg=white">AdCheck</a>, <a href="https://tw.buy.yahoo.com/act/activity/clearance.html?co_servername=yGroupbuy_24h&amp;utm_source=yahoo&amp;utm_medium=ecbe&amp;utm_campaign=24h" target="_blank"><img border="0" src="https://s.yimg.com/cv/apiv2/twfrontpage/fallbackimage/SW1_24h_201910.jpg" style="width: 100%"/></a>, <a href="https://shop.cosmed.com.tw/?utm_source=YAHOO&amp;utm_medium=&amp;utm_campaign=_%E9%A6%96%E9%A0%81%E4%BA%BA%E6%B0%A3%E9%80%9F%E5%A0%B1_10021029" target="_blank"><img border="0" src="https://s.yimg.com/cv/apiv2/twfrontpage/fallbackimage/H1_cosmed_201910.JPG" style="width: 100%"/> </a>, <a class="" data-ylk="t1:a4;t2:ft;t3:lst;sec:ft;elm:itm;elmt:link;itc:0;rspns:nav;" href="https://info.yahoo.com/legal/tw/yahoo/utos/zh-hant-tw/">服務條款 (更新)</a>, <a class="" data-ylk="t1:a4;t2:ft;t3:lst;sec:ft;elm:itm;elmt:link;itc:0;rspns:nav;" href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/index.htm">隱私權 (更新)</a>, <a class="" data-ylk="t1:a4;t2:ft;t3:lst;sec:ft;elm:itm;elmt:link;itc:0;rspns:nav;" href="https://tw.help.yahoo.com/kb/helpcentral">服務中心</a>, <a class="" data-ylk="t1:a4;t2:ft;t3:lst;sec:ft;elm:itm;elmt:link;itc:0;rspns:nav;" href="https://tw.safely.yahoo.com/">家庭網路安全</a>, <a class="" data-ylk="t1:a4;t2:ft;t3:lst;sec:ft;elm:itm;elmt:link;itc:0;rspns:nav;" href="http://yahoo-emarketing.tumblr.com/">網路行銷</a>, <a class="" data-ylk="t1:a4;t2:ft;t3:lst;sec:ft;elm:itm;elmt:link;itc:0;rspns:nav;" href="http://yahoo-smbmarketing.tumblr.com/">中小企業行銷</a>, <a class="" data-ylk="t1:a4;t2:ft;t3:lst;sec:ft;elm:itm;elmt:link;itc:0;rspns:nav;" href="https://www.oath.com/zh-tw/careers/work-at-oath/">Yahoo奇摩徵才</a>, <a class="" data-ylk="t1:a4;t2:ft;t3:lst;sec:ft;elm:itm;elmt:link;itc:0;rspns:nav;" href="http://ycorpblog.tumblr.com/">Yahoo奇摩官方部落格</a>, <a class="" data-ylk="t1:a4;t2:ft;t3:lst;sec:ft;elm:itm;elmt:link;itc:0;rspns:nav;" href="https://www.facebook.com/Yahoo.Kimo">Yahoo奇摩粉絲團</a>]

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="StencilRoot my3columns l-out Pos-r https fp fp-default uh-topbar-on ltr desktop Desktop bkt900" id="Stencil" lang="zh-Hant-TW">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Yahoo奇摩
#   </title>
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="//s.yimg.com" rel="dns-prefetch"/>
#   <link href="//s.yimg.com" rel="preconnect"/>
#   <link href="//csc.beap.bc.yahoo.com" rel="dns-prefetch"/>
#   <link href="//csc.beap.bc.yahoo.com" rel="preconnect"/>
#   <link href="//geo.yahoo.com" rel="dns-prefetch"/>
#   <link href="//geo.yahoo.com" rel="preconnect"/>
#   <link href="//comet.yahoo.com" rel="dns-prefetch"/>
#   <link href="//comet.yahoo.com" rel="preconnect"/>
#   <link href="//video-api.yql.yahoo.com" rel="dns-prefetch"/>
#   <link href="//video-api.yql.yahoo.com" rel="preconnect"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="新聞、電子信箱和搜尋功能只是起點。每天發掘更多精彩內容。打造專屬自我的 Yahoo奇摩體驗。" name="description"/>
#   <meta content="yahoo, yahoo奇摩, yahoo奇摩首頁, yahoo首頁, yahoo搜尋, yahoo 信箱, yahoo 即時通訊, 新聞, 股市, 運動, 娛樂, 拍賣, 購物中心, 超級商城" name="keywords"/>
#   <meta content="Yahoo奇摩" property="og:title">
#    <meta content="website" property="og:type">
#     <meta content="http://tw.yahoo.com" property="og:url">
#      <meta content="新聞、電子信箱和搜尋功能只是起點。每天發掘更多精彩內容。打造專屬自我的 Yahoo奇摩體驗。" property="og:description">
#       <meta content="https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png" property="og:image">
#        <meta content="Yahoo奇摩" property="og:site_name"/>
#        <meta content="399384933466174" property="fb:app_id"/>
#        <meta content="telephone=no" name="format-detection"/>
#        <link href="https://s.yimg.com/cv/apiv2/default/icons/favicon_y19_32x32_custom.svg" mask="" rel="icon" sizes="any"/>
#        <meta content="#400090" name="theme-color"/>
#        <link href="https://s.yimg.com/rz/l/favicon.ico" rel="shortcut icon">
#         <link href="https://tw.yahoo.com/" rel="canonical">
#          <meta content="230899156962824" property="fb:pages">
#           <meta content="unsafe-url" name="referrer"/>
#           <link href="https://s.yimg.com/os/stencil/3.2.1/styles-ltr.css" rel="stylesheet" type="text/css"/>
#           <link href="https://s.yimg.com/nn/lib/metro/g/theme/yglyphs-legacy_0.0.43.css" rel="stylesheet" type="text/css"/>
#           <link href="https://s.yimg.com/nn/lib/metro/g/myy/fp_0.0.80.css" rel="stylesheet" type="text/css"/>
#           <link href="https://s.yimg.com/nn/lib/metro/g/theme/partner_abu_0.0.121.css" rel="stylesheet" type="text/css"/>
#           <link href="https://s.yimg.com/nn/lib/metro/g/theme/partner_abu_video_0.0.22.css" rel="stylesheet" type="text/css"/>
#           <link href="https://s.yimg.com/nn/lib/metro/g/sda/fp_sda_0.0.52.css" rel="stylesheet" type="text/css"/>
#           <link href="https://tw.search.yahoo.com/opensearch.xml" rel="search" title="Yahoo奇摩搜尋" type="application/opensearchdescription+xml">
#            <link href="https://s.yimg.com/zz/combo?yui:3.12.0/widget-base/assets/skins/sam/widget-base.css&amp;yui:3.12.0/widget-stack/assets/skins/sam/widget-stack.css&amp;yui:3.12.0/overlay/assets/skins/sam/overlay.css&amp;yui:3.12.0/autocomplete-list/assets/skins/sam/autocomplete-list.css&amp;yui:3.12.0/app-transitions-css/app-transitions-css-min.css" rel="stylesheet" type="text/css">
#             <script>
#              var myYahoostartTime = new Date(),
#         afPerfHeadStart=new Date().getTime(),
#         ie;
#
#     ie = (function(){
#
#     var undef,
#         v = 3,
#         div = document.createElement('div'),
#         all = div.getElementsByTagName('i');
#
#     while (
#         div.innerHTML = '<!--[if gt IE ' + (++v) + ']><i></i><![endif]-->',
#         all[0]
#     );
#
#     return v > 4 ? v : undef;
#
# }());
#
# if(ie && ie <9 ) {
#     if (document.documentElement.clientWidth > 980) {
#          document.documentElement.className += " centered-aligned-layout";
#      }
# } else {
#     document.documentElement.className += " centered-aligned-layout";
# }
#     document.documentElement.className += ' JsEnabled jsenabled';/* Modernizr 2.6.2 (Custom Build) | MIT & BSD
#  * Build: http://modernizr.com/download/#-touch-cssclasses-teststyles-prefixes
#  */
# window.Modernizr=function(a,b,c){function w(a){j.cssText=a}function x(a,b){return w(m.join(a+";")+(b||""))}function y(a,b){return typeof a===b}function z(a,b){return!!~(""+a).indexOf(b)}function A(a,b,d){for(var e in a){var f=b[a[e]];if(f!==c)return d===!1?a[e]:y(f,"function")?f.bind(d||b):f}return!1}var d="2.6.2",e={},f=!0,g=b.documentElement,h="modernizr",i=b.createElement(h),j=i.style,k,l={}.toString,m=" -webkit- -moz- -o- -ms- ".split(" "),n={},o={},p={},q=[],r=q.slice,s,t=function(a,c,d,e){var f,i,j,k,l=b.createElement("div"),m=b.body,n=m||b.createElement("body");if(parseInt(d,10))while(d--)j=b.createElement("div"),j.id=e?e[d]:h+(d+1),l.appendChild(j);return f=["&#173;",'<style id="s',h,'">',a,"</style>"].join(""),l.id=h,(m?l:n).innerHTML+=f,n.appendChild(l),m||(n.style.background="",n.style.overflow="hidden",k=g.style.overflow,g.style.overflow="hidden",g.appendChild(n)),i=c(l,a),m?l.parentNode.removeChild(l):(n.parentNode.removeChild(n),g.style.overflow=k),!!i},u={}.hasOwnProperty,v;!y(u,"undefined")&&!y(u.call,"undefined")?v=function(a,b){return u.call(a,b)}:v=function(a,b){return b in a&&y(a.constructor.prototype[b],"undefined")},Function.prototype.bind||(Function.prototype.bind=function(b){var c=this;if(typeof c!="function")throw new TypeError;var d=r.call(arguments,1),e=function(){if(this instanceof e){var a=function(){};a.prototype=c.prototype;var f=new a,g=c.apply(f,d.concat(r.call(arguments)));return Object(g)===g?g:f}return c.apply(b,d.concat(r.call(arguments)))};return e}),n.touch=function(){var c;return"ontouchstart"in a||a.DocumentTouch&&b instanceof DocumentTouch?c=!0:t(["@media (",m.join("touch-enabled),("),h,")","{#modernizr{top:9px;position:absolute}}"].join(""),function(a){c=a.offsetTop===9}),c};for(var B in n)v(n,B)&&(s=B.toLowerCase(),e[s]=n[B](),q.push((e[s]?"":"no-")+s));return e.addTest=function(a,b){if(typeof a=="object")for(var d in a)v(a,d)&&e.addTest(d,a[d]);else{a=a.toLowerCase();if(e[a]!==c)return e;b=typeof b=="function"?b():b,typeof f!="undefined"&&f&&(g.className+=" "+(b?"":"no-")+a),e[a]=b}return e},w(""),i=k=null,e._version=d,e._prefixes=m,e.testStyles=t,g.className=g.className.replace(/(^|\s)no-js(\s|$)/,"$1$2")+(f?" js "+q.join(" "):""),e}(this,this.document);
#             </script>
#             <meta content="guce.yahoo.com" name="oath:guce:consent-host">
#              <!-- Consent Manager Tag : Stubbed -->
#              <script type="text/javascript">
#               /*! CMP 2.18.1 Copyright 2018 Oath Holdings, Inc. */!function(e){var t={};function n(r){if(t[r])return t[r].exports;var o=t[r]={i:r,l:!1,exports:{}};return e[r].call(o.exports,o,o.exports,n),o.l=!0,o.exports}n.m=e,n.c=t,n.d=function(e,t,r){n.o(e,t)||Object.defineProperty(e,t,{configurable:!1,enumerable:!0,get:r})},n.n=function(e){var t=e&&e.__esModule?function(){return e.default}:function(){return e};return n.d(t,"a",t),t},n.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},n.p="/",n(n.s=2)}({2:function(e,t){!function(){var e=!1;function t(e){var t="string"==typeof e.data,n=e.data;if(t)try{n=JSON.parse(e.data)}catch(e){}if(n&&n.__cmpCall){var r=n.__cmpCall;window.__cmp(r.command,r.parameter,function(n,o){var a={__cmpReturn:{returnValue:n,success:o,callId:r.callId}};e&&e.source&&e.source.postMessage(t?JSON.stringify(a):a,"*")})}}"function"==typeof __cmp||(window.__cmp=function(){var t=arguments;if(__cmp.a=__cmp.a||[],!t.length)return __cmp.a;"ping"===t[0]?t[2]({gdprAppliesGlobally:e,cmpLoaded:!1},!0):__cmp.a.push([].slice.apply(t))},function e(){if(document.body&&document.body.firstChild){var t=document.body,n=document.createElement("iframe");n.style.display="none",n.height=n.width=0,n.name="__cmpLocator",t.insertBefore(n,t.firstChild)}else setTimeout(e,5)}(),window.addEventListener?window.addEventListener("message",t,!1):window.attachEvent("onmessage",t))}()}});
#              </script>
#              <!-- Consent Manager Tag : Script -->
#              <script async="" src="https://s.yimg.com/aaq/cmp/version/2.18.1/cmp.js" type="text/javascript">
#              </script>
#             </meta>
#            </link>
#           </link>
#          </meta>
#         </link>
#        </link>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="my3columns l-out Pos-r https fp fp-default uh-topbar-on ltr " dir="ltr" id="">
#   <noscript>
#   </noscript>
#   <div id="darla-assets-js-top">
#    <script src="https://s.yimg.com/rq/darla/3-17-1/js/g-r-min.js" type="text/javascript">
#    </script>
#   </div>
#   <script type="text/javascript">
#    var rapidPageConfig = {
#             rapidEarlyConfig : {},
#             rapidConfig: {"compr_type":"deflate","tracked_mods":["Footer","IntlSelector"],"spaceid":152963594,"click_timeout":800,"track_right_click":true,"apv":true,"apv_time":0,"async_all_clicks":false,"compr_on":true,"yql_host":"udc.yahoo.com","yql_path":"\/v2\/public\/yql","test_id":"900","client_only":0,"pageview_on_init":true,"perf_navigationtime":2,"addmodules_timeout":300,"extendbcookie":false,"keys":{"_rid":"0clhhaheqdgbn","mrkt":"tw","pt":"home","site":"fp","ver":"ss","uh_vw":0,"colo":"tp2","navtype":"server","nob":1,"abk":""},"dwell_on":true},
#             rapidSingleInstance: 0
#         };
#                 var avpRapidCallBack = function(apvObj) {
#             try {
#                 var spaceid=YAHOO && YAHOO.i13n && YAHOO.i13n.SPACEID;
#                 if (152963594 == spaceid) {
#                    var img = new Image();
#                    img.src = "/p.gif?beaconType=apv&sp=" + spaceid + "&device=desktop&intl=tw&pixel_pos=" + apvObj.pixel_pos + "&scroll_dir=" + apvObj.scroll_dir;
#                 }
#             } catch (e) {}
#             if (window.sdaAvpCallback) {
#                 window.sdaAvpCallback();
#             }
#         };
#         rapidPageConfig.rapidConfig.apv_callback = avpRapidCallBack;
#
#         try {
#             if (YAHOO && YAHOO.i13n && YAHOO.i13n.Rapid) {
#                 YAHOO.i13n.WEBWORKER_FILE = '/lib/metro/g/myy/rapidworker_1_2_0.0.38.js';
#             }
#         } catch (e) {}
#   </script>
#   <div id="my-adsHPSPON-base">
#    <div class="Ta-c Mt-10 Mb-20 Pos-r Ta(c) Mb(20px) Pos(r)" id="my-adsHPSPON">
#     <div class="Mx-a">
#      <!-- SpaceID=0 robot -->
#     </div>
#    </div>
#   </div>
#   <div id="MasterWrap">
#    <div class="header Mb-0 M-0 js-applet Zoom-1 " data-applet-guid="p_30345894" data-applet-params="_suid:30345894" data-applet-type="header" data-i13n="auto:true;sec:uh" data-i13n-sec="uh" data-ylk="rspns:nav;t1:a1;t2:hd;itc:0;" id="applet_p_30345894">
#     <!-- App open -->
#     <style>
#      #Stencil body{margin-top:104px!important;line-height:1.25!important;-moz-hyphens:none!important;-webkit-hyphens:none!important;-ms-hyphens:none!important;-o-hyphens:none!important;hyphens:none!important}#Stencil #Eyebrow{height:28px;margin-bottom:14px}#Stencil #Eyebrow .promotion{right:5%;padding-left:15px;top:2px}#Stencil #Eyebrow .promotion-text:hover{text-decoration:underline}#Stencil #Eyebrow .promotion-icon{top:4px}#Stencil #Eyebrow>ul{max-width:1180px;width:auto;*width:1180px;margin:0 auto}#Stencil #UH .y-logo{background-size:100%;background-repeat:no-repeat;width:154px;overflow:hidden}#Stencil #UHSearchBox{height:34px;line-height:2em\9;*line-height:2em;padding-top:0;padding-bottom:0;*padding:0;border:1px solid #cdced6;-moz-border-radius:2px;-webkit-border-radius:2px;border-radius:2px}#Stencil input::-ms-clear{display:none}#Stencil #uhWrapper{height:60px}#Stencil #UHSearchBoxWrapper{*padding-right:4px}#Stencil #UHSearchBox:focus{-o-box-shadow:0 0 9px 0 rgba(80,0,149,.5)!important;-moz-box-shadow:0 0 9px 0 rgba(80,0,149,.5)!important;-webkit-box-shadow:0 0 9px 0 rgba(80,0,149,.5)!important;box-shadow:0 0 9px 0 rgba(80,0,149,.5)!important;border-color:#7590f5!important}#Stencil #UHSearchProperty,#Stencil #UHSearchWeb{height:34px!important;*height:36px!important;*margin-top:1px;line-height:32px!important;width:100px;font-family:"Helvetica Neue",Helvetica,Arial,STHeiti,"Microsoft JhengHei",微軟正黑體,sans-serif}#Stencil #pphw-triggerbtn{height:25px;width:25px}#Stencil #UH .yui3-aclist{border:1px solid #a8aaad;left:-1px!important}#Stencil #UH .yui3-aclist .yui3-aclist-list{background-color:#fff;font-weight:600;padding:0}#Stencil #UH .yui3-aclist-item{padding:0 0 0 8px;line-height:28px;color:#231f20;font-weight:400;font-size:16px}#Stencil #UH .yui3-aclist-item a{color:#231f20}#Stencil #UH .yui3-aclist .yui3-aclist-item-active,#Stencil #UH .yui3-aclist .yui3-aclist-item-hover{background:none repeat scroll 0 0 #f1f1f1}#Stencil .keywords{height:1.2em}#Stencil #UH{height:92px}#Stencil .show-keywords#UH{height:103px}#Stencil .user-info .tab-user .tab-label{max-width:150px}#Stencil .user-info .user-icon{color:gray}#Stencil .user-info .login-container{color:#afafb8;margin-left:38px}#Stencil .user-info .connected-lbl{color:#5f5f5f}#Stencil .user-info .y-social-login-menu .login-btn-facebook{border-top:1px solid #f1f1f1;border-bottom:1px solid #f1f1f1}#Stencil .user-info .mail-icon{color:#6e329d}#Stencil .user-info .login-btn-yahoo{border-bottom:1px solid #f1f1f1}#Stencil .mail-badge{text-align:center;position:absolute;top:-10px;left:-6px;color:#fff;border:1px solid #e04544;font-size:11px;border-radius:100px;min-width:15px;height:15px;line-height:15px;background:#e04544}#Stencil span.yucs-mail-count{color:#fff;background-color:#e02727;padding:0 5px;margin-left:5px;-moz-border-radius:6px;-webkit-border-radius:6px;border-radius:6px}#Stencil #yucs-mail-panel{width:240px!important}#Stencil #yucs-mail-panel .yucs-mailpreview-from{max-width:110px}.yui3-pphw-overlay-hidden{display:none}#pphw-cleanbtn,#pphw-closebtn,#pphw-label-left,#pphw-qmarkbtn,#pphw-undobtn,.pphw-panel{background:url(https://sp.yimg.com/mq/i/home/pphw_sprites_20101019.png) no-repeat}.pphw-panel{overflow:hidden;width:256px;height:263px;background:#fff;border:1px solid #d9d9d9;box-shadow:0 2px 4px rgba(34,25,25,.1);border-radius:2px}.pphw-panel .yui3-widget-hd{height:29px;overflow:hidden}.pphw-panel #pphw-hd-label{color:#999}.pphw-panel .yui3-widget-hd span{display:block;margin:4px 0 0 60px;line-height:25px;font-size:12px}.pphw-panel .yui3-widget-bd{overflow:hidden;height:205px}.pphw-panel .btn-wrapper button{margin:0;padding:0;background-color:#fff;border:0 none;cursor:pointer;position:absolute}.pphw-panel .pp-gf{width:27%;margin:0 0 0 4px;height:205px;overflow:hidden}.pphw-panel .pp-gf button{width:31px;height:31px;text-align:center;border:1px double #d0d0d0;color:#333;top:29px;left:14px;font-size:16px;z-index:1}.pphw-panel .pp-gf #pphw-cbtn2{top:59px}.pphw-panel .pp-gf #p ...
#     </style>
#     <style>
#      #Stencil #UHSearch{width:100%}#Stencil #UHSearchBoxContainer{padding:0}#Stencil #UHSearchBox{height:50px;padding:13px 20px 12px 20px;*padding:13px 20px 12px 20px;-moz-border-top-right-radius:0!important;-webkit-border-top-right-radius:0!important;border-top-right-radius:0!important;-moz-border-bottom-right-radius:0!important;-webkit-border-bottom-right-radius:0!important;border-bottom-right-radius:0!important;border-color:#aaa!important;border-right-width:0!important;font-size:18px}#Stencil #UHSearchBox:focus{-o-box-shadow:none!important;-moz-box-shadow:none!important;-webkit-box-shadow:none!important;box-shadow:none!important;border-color:#0f69ff!important}#Stencil #UHSearchBox:hover{border-color:#aaa!important}#Stencil #UHSearchBoxDel{margin-top:13px;margin-right:13px;margin-bottom:13px;color:#aaa}#Stencil #UHSearchWebContainer{padding:0}#Stencil #UHSearchWeb{width:80px;height:50px!important;border:none;border-radius:0 6px 6px 0!important;background-color:#5701ed;background-image:url(https://s.yimg.com/pv/static/img/header_2x-1479864976616.min.png);background-position:center 10px;background-size:30px 177px;background-repeat:no-repeat;box-shadow:none!important}#Stencil #UHSearchWeb.glow{-webkit-transition:all .75s ease-in;-moz-transition:all .75s ease-in;-o-transition:all .75s ease-in;transition:all .75s ease-in}#Stencil #UHSearchWeb.blue-btn{background-color:#0f69ff!important}#Stencil #UHSearchWeb.blue-btn:hover{background-color:#015eff!important}#Stencil #UH .yui3-aclist{box-sizing:border-box;top:50px!important;left:0!important;border-radius:0 0 2px 2px;border-top:none}#Stencil #UH .yui3-aclist .yui3-aclist-list{padding-top:10px;padding-bottom:9px}#Stencil #UH .yui3-aclist-item{padding-left:20px;font-size:18px}#Stencil #UH .UHCol3{padding-top:7px!important}#Stencil #UH #pphw-triggerbtn{margin-left:15px!important;background-image:url(https://real-hk.yimg.com/i/home/pphw_sprites_20101019.png);background-size:311px 297px;background-position:-101px 0}
#     </style>
#     <style>
#      #Stencil .show-keywords#UH{height:113px!important}
#     </style>
#     <style>
#      .intl-flag{background-image:url(https://s.yimg.com/dh/ap/default/140317/pc_flags_sprite_0317_Regular_630pm.png);*background-image:url(https://s.yimg.com/dh/ap/default/140317/pc_flags_sprite_0317_IE6_630pm.png);_background-image:url(https://s.yimg.com/dh/ap/default/140317/pc_flags_sprite_0317_IE6_630pm.png);background-size:235px 60px;height:13px;width:20px}#IntlSelector .flag-au{background-position:-148px -15px}#IntlSelector .flag-nz{background-position:-148px -29px}#IntlSelector .flag-hk{background-position:-106px -43px}#IntlSelector .flag-in{background-position:-106px -15px}#IntlSelector .flag-tw{background-position:-106px -29px}#IntlSelector .flag-b2,#IntlSelector .flag-b3{background-position:-1px -43px}#IntlSelector .flag-de{background-position:-22px -15px}#IntlSelector .flag-fr{background-position:-64px -1px}#IntlSelector .flag-gr{background-position:-64px -29px}#IntlSelector .flag-ie{background-position:-43px -1px}#IntlSelector .flag-it{background-position:-64px -15px}#IntlSelector .flag-ro{background-position:-22px -43px}#IntlSelector .flag-es{background-position:-1px -15px}#IntlSelector .flag-se{background-position:-43px -29px}#IntlSelector .flag-uk{background-position:-22px 1px}#IntlSelector .flag-za{background-position:-43px -15px}#IntlSelector .flag-ca{background-position:-1px -29px}#IntlSelector .flag-cf{background-position:-22px -29px}#IntlSelector .flag-mx{background-position:-85px -1px}#IntlSelector .flag-e1,#IntlSelector .flag-us{background-position:-1px -1px}#IntlSelector .flag-ar{background-position:-64px -43px}#IntlSelector .flag-br{background-position:-43px -43px}#IntlSelector .flag-cl{background-position:-85px -15px}#IntlSelector .flag-co{background-position:-85px -29px}#IntlSelector .flag-pe{background-position:-106px -1px}#IntlSelector .flag-ve{background-position:-85px -43px}#IntlSelector .flag-sg{background-position:-127px -1px}#IntlSelector .flag-ph{background-position:-127px -15px}#IntlSelector .flag-id{background-position:-127px -29px}#IntlSelector .flag-vn{background-position:-127px -43px}#IntlSelector .flag-my{background-position:-148px -1px}#IntlSelector .flag-xa,#IntlSelector .flag-xe{background-position:-169px -1px}
#     </style>
#     <style>
#      #Stencil #UHSearchBoxContainer{width:auto;border:1px solid transparent;border-top:0;border-bottom:0}#Stencil #UHSearchBoxContainer.sa-visible{display:block;border-color:#a8aaad;border-top-left-radius:23px!important;border-top-right-radius:23px!important}#Stencil #UHSearchBoxContainer #UHSearchBox{height:46px!important;border-radius:23px!important;margin-left:-1px}#Stencil #UHSearchBoxContainer .yui3-aclist{margin-top:-4px;margin-left:-1px;width:100%;box-sizing:content-box}#Stencil #UHSearchBoxContainer .yui3-aclist .yui3-aclist-list{padding-top:20px;margin-top:0}#Stencil #UHSearchBoxContainer .yui3-aclist,#Stencil #UHSearchBoxContainer .yui3-aclist .yui3-aclist-list{border-radius:0 0 8px 8px}#Stencil #UHSearchBoxContainer #UHSearchBoxDel{margin-top:11px;margin-right:83px}#Stencil #UHSearchWebContainer{width:0;position:absolute;top:0;right:0;z-index:1}#Stencil #UHSearchWebContainer #UHSearchWeb{border:solid 1px transparent!important;border-radius:23px!important;width:73.6px!important;height:46px!important;background-position:23px 9px;background-size:28px 159px;position:absolute;top:0;right:0}#Stencil #UHSearchWebContainer #UHSearchWeb.blue-btn{border-color:#188fff;background-color:#188fff!important}#Stencil #UHSearchWebContainer #UHSearchWeb.blue-btn:hover{background-color:#003abc!important}#Stencil #UH #pphw-triggerbtn{background-size:156px 168px;background-position:0 -150px;background-image:url(https://s.yimg.com/pv/static/img/pphw_sprites-775e15deb23bd2d4ff74723e324444a7.png);width:18px;height:18px;margin-top:9px}#Stencil #uhWrapper .keywords .keyword a{padding-left:10px;padding-right:10px;border-left:1px solid #d6d6d6}#Stencil #uhWrapper .keywords .keyword.first a{padding-left:0;border-left:none}
#     </style>
#     <div class="App-Bd">
#      <div class="App-Main" data-region="main">
#       <div class="js-applet-view-container-main">
#        <style>
#         #Stencil #UH .yui3-aclist-item .yui3-highlight {
#   color: #080;
# }
#
#
# #Stencil body {
#   margin-top: 115px !important;
# }
#        </style>
#        <!-- global param to track client side performance -->
#        <script>
#         window.perfStart = new Date().getTime();
#        </script>
#        <div class="Cf tw Bgc-w Pb-12 show-keywords" id="UH">
#         <div id="Eyebrow">
#          <ul class="Lh-18 Reset Whs-nw Pos-r" role="navigation">
#           <li class="Grid-U Py-2 Mend-18">
#            <a data-ylk="sec:eyebrow;subsec:property;" href="/">
#             <i class="Fl-start Mend-4 Icon" id="my-home" style="margin-top:-.1em">
#              
#             </i>
#             首頁
#            </a>
#           </li>
#           <li class="Grid-U Py-2 Mend-18 Pstart-12">
#            <a data-ylk="sec:eyebrow;subsec:property;" href="https://tw.mail.yahoo.com">
#             信箱
#            </a>
#           </li>
#           <li class="Grid-U Py-2 Mend-18 ">
#            <a data-ylk="sec:eyebrow;subsec:property;" href="https://tw.news.yahoo.com">
#             新聞
#            </a>
#           </li>
#           <li class="Grid-U Py-2 Mend-18 ">
#            <a data-ylk="sec:eyebrow;subsec:property;" href="https://tw.stock.yahoo.com">
#             股市
#            </a>
#           </li>
#           <li class="Grid-U Py-2 Mend-18 ">
#            <a data-ylk="sec:eyebrow;subsec:property;" href="https://tw.news.yahoo.com/weather/">
#             氣象
#            </a>
#           </li>
#           <li class="Grid-U Py-2 Mend-18 ">
#            <a data-ylk="sec:eyebrow;subsec:property;" href="https://tw.sports.yahoo.com/">
#             運動
#            </a>
#           </li>
#           <li class="Grid-U Py-2 Mend-18 ">
#            <a data-ylk="sec:eyebrow;subsec:property;" href="https://tw.tv.yahoo.com/">
#             Yahoo TV
#            </a>
#           </li>
#           <li class="Grid-U Py-2 Mend-18 ">
#            <a data-ylk="sec:eyebrow;subsec:property;" href="https://tw.news.yahoo.com/entertainment">
#             娛樂
#            </a>
#           </li>
#           <li class="Grid-U Py-2 Mend-18 ">
#            <a data-ylk="sec:eyebrow;subsec:property;" href="https://tw.buy.yahoo.com/?co_servername=sUH&amp;c2=sUH ">
#             購物中心
#            </a>
#           </li>
#           <li class="Grid-U Py-2 Mend-18 ">
#            <a data-ylk="sec:eyebrow;subsec:property;" href="https://tw.mall.yahoo.com/?_co=pUH&amp;_co2=pUH">
#             商城
#            </a>
#           </li>
#           <li class="Grid-U Py-2 Mend-18 ">
#            <a data-ylk="sec:eyebrow;subsec:property;" href="https://tw.bid.yahoo.com/?co_servername=aUH&amp;co_servername2=aUH">
#             拍賣
#            </a>
#           </li>
#           <li class="Grid-U Py-2 Pstart-10 Pend-6 Pos-r Z-1 MoreDropDown yucs-menu yucs-more-activate" id="yucs-more">
#            <a class="NoTextDecoration Pos-r Z-1 yucs-leavable rapidnofollow" data-plugin="toggle" data-toggle='[{"target":".MoreDropDown-Box","click":{"toggle":{"classnames":"Hidden"}}}, {"target-ancestor":".MoreDropDown","click":{"toggle":{"classnames":"MoreDropDown-on"}}}]' href="" id="yucs-more-link" role="button">
#             <i class="Lh-1 D-ib">
#              更多
#             </i>
#             <i class="Icon Fz-m Va-m Lh-1 W-a Mstart-2" style="*vertical-align: bottom;">
#              
#             </i>
#            </a>
#            <div class="Pos-a Start-0 T-100 MoreDropDown-Box Hidden">
#             <iframe aria-hidden="true" class="Pos-a Start-0 W-100 H-100 Bd-0" frameborder="0" tabindex="-1">
#             </iframe>
#             <ul class="Pos-r Px-10">
#              <li>
#               <a class="D-b" href="https://tw.answers.yahoo.com/">
#                知識+
#               </a>
#              </li>
#              <li>
#               <a class="D-b" href="https://tw.dictionary.search.yahoo.com/">
#                字典
#               </a>
#              </li>
#              <li>
#               <a class="D-b" href="https://tw.money.yahoo.com/">
#                理財
#               </a>
#              </li>
#              <li>
#               <a class="D-b" href="https://autos.yahoo.com.tw/">
#                汽車機車
#               </a>
#              </li>
#              <li>
#               <a class="D-b" href="https://movies.yahoo.com.tw/">
#                電影
#               </a>
#              </li>
#              <li>
#               <a class="D-b" href="https://games.yahoo.com.tw/">
#                遊戲
#               </a>
#              </li>
#              <li>
#               <a class="D-b" href="https://travel.yahoo.com.tw/">
#                旅遊
#               </a>
#              </li>
#              <li>
#               <a class="D-b" href="https://house.yahoo.com.tw/">
#                房地產
#               </a>
#              </li>
#              <li>
#               <a class="D-b" href="https://style.yahoo.com.tw/">
#                時尚美妝
#               </a>
#              </li>
#              <li>
#               <a class="D-b" href="https://tw.news.yahoo.com/technology">
#                3C科技
#               </a>
#              </li>
#              <li>
#               <a class="D-b" href="https://tw.buy.yahoo.com/bestbuy?co_servername=yUHDab">
#                每日好康
#               </a>
#              </li>
#             </ul>
#            </div>
#           </li>
#           <li class="Pos-a Fw-b promotion">
#            <a class="C-w Cur-p promotion-text" data-ylk="rspns:nav;t1:a3;t2:uh;t3:ct;sec:eyebrow;subsec:hpset;slk:hpset;elm:btn;elmt:ct;itc:1;" href="https://tw.help.yahoo.com/kb/SLN2208.html" target="_blank">
#             設定 Yahoo 為首頁
#            </a>
#           </li>
#           <li class="Pos-a End-0" id="IntlSelector">
#            <a class="Mt-2 D-b Ta-end NoTextDecoration rapidnofollow" data-plugin="tooltip" data-tooltip='{"default":{"toggle":{"position":"bfr","width":"610px","id":"intl-tooltip", "parent":"#yucs-top-intls"}}}' data-trigger="click" data-ylk="sec:eyebrow;subsec:lang;slk:select;" href="#0" onclick="arguments[0].preventDefault();">
#             <i class="Va-m D-ib intl-flag flag-tw">
#             </i>
#             <i class="Icon Fz-m Va-m Lh-1 W-a C-1">
#              
#             </i>
#            </a>
#            <div class="D-n" id="intl-tooltip">
#             <div class="P-20 Grid">
#              <h3 class="D-b Fw-b Fz-s Mt-0 Mb-8 Bd-b Pb-16 Row C-n">
#               世界Yahoo!
#              </h3>
#              <div class="D-ib Va-t Grid-U-1-4 Ov-h">
#               <h4 class="Fw-b Fz-s Mb-10 C-n">
#                亞太地區
#               </h4>
#               <ul>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Australia;" href="https://au.yahoo.com/?p=dnr" target="_top">
#                  Australia
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:香港;" href="https://hk.yahoo.com/?p=dnr" target="_top">
#                  香港
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:India;" href="https://in.yahoo.com/" target="_top">
#                  India
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Indonesia;" href="https://id.yahoo.com/" target="_top">
#                  Indonesia
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:New Zealand;" href="https://nz.yahoo.com/?p=dnr" target="_top">
#                  New Zealand
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Philippines;" href="https://ph.yahoo.com/" target="_top">
#                  Philippines
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Singapore;" href="https://sg.yahoo.com/" target="_top">
#                  Singapore
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Malaysia;" href="https://malaysia.yahoo.com/" target="_top">
#                  Malaysia
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <span class="Ell C-2 zh-Hant-TW zh-Hant-TW">
#                  臺灣
#                 </span>
#                 <i class="Icon Pstart-4 Fz-2xs">
#                  
#                 </i>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Việt Nam;" href="https://vn.yahoo.com/" target="_top">
#                  Việt Nam
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:日本;" href="http://www.yahoo.co.jp/" target="_top">
#                  日本
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="D-ib Va-t Grid-U-1-4 Ov-h">
#               <h4 class="Fw-b Fz-s Mb-10 C-n">
#                歐洲地區
#               </h4>
#               <ul>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:België (nl);" href="https://be.yahoo.com/" target="_top">
#                  België (nl)
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Belgique (fr);" href="https://fr-be.yahoo.com/" target="_top">
#                  Belgique (fr)
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Deutschland;" href="https://de.yahoo.com/" target="_top">
#                  Deutschland
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:France;" href="https://fr.yahoo.com/" target="_top">
#                  France
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Ελλάδα;" href="https://gr.yahoo.com/" target="_top">
#                  Ελλάδα
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Ireland;" href="https://ie.yahoo.com/" target="_top">
#                  Ireland
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Italia;" href="https://it.yahoo.com/" target="_top">
#                  Italia
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:România;" href="https://ro.yahoo.com/" target="_top">
#                  România
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:España;" href="https://es.yahoo.com/" target="_top">
#                  España
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Sverige;" href="https://se.yahoo.com/" target="_top">
#                  Sverige
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:United Kingdom;" href="https://uk.yahoo.com/" target="_top">
#                  United Kingdom
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="D-ib Va-t Grid-U-1-4 Ov-h">
#               <h4 class="Fw-b Fz-s Mb-10 C-n">
#                中東及非洲地區
#               </h4>
#               <ul>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Maktoob (eng);" href="https://en-maktoob.yahoo.com/" target="_top">
#                  Maktoob (eng)
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:مكتوب (العربية);" href="https://maktoob.yahoo.com/" target="_top">
#                  مكتوب (العربية)
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:South Africa;" href="https://za.yahoo.com/" target="_top">
#                  South Africa
#                 </a>
#                </li>
#               </ul>
#               <h4 class="Fw-b Fz-s Mb-10 C-n">
#                北美洲地區
#               </h4>
#               <ul>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Canada (eng);" href="https://ca.yahoo.com/" target="_top">
#                  Canada (eng)
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Canada (fr);" href="https://qc.yahoo.com/" target="_top">
#                  Canada (fr)
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:México;" href="https://mx.yahoo.com/" target="_top">
#                  México
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:US (eng);" href="https://us.yahoo.com" target="_top">
#                  US (eng)
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Estados Unidos (es);" href="https://espanol.yahoo.com/" target="_top">
#                  Estados Unidos (es)
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="D-ib Va-t Grid-U-1-4 Ov-h">
#               <h4 class="Fw-b Fz-s Mb-10 C-n">
#                南美洲地區
#               </h4>
#               <ul>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Argentina;" href="https://ar.yahoo.com/" target="_top">
#                  Argentina
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Brasil;" href="https://br.yahoo.com/" target="_top">
#                  Brasil
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Chile;" href="https://cl.yahoo.com/" target="_top">
#                  Chile
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Colombia;" href="https://co.yahoo.com/" target="_top">
#                  Colombia
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Perú;" href="https://pe.yahoo.com/" target="_top">
#                  Perú
#                 </a>
#                </li>
#                <li class="Mb-8">
#                 <a class="Ell C-2 zh-Hant-TW zh-Hant-TW" data-ylk="sec:uh-intl;slk:Venezuela;" href="https://ve.yahoo.com/" target="_top">
#                  Venezuela
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#           </li>
#          </ul>
#         </div>
#         <div class="Ma" id="uhWrapper">
#          <table class="Ma My-0 W-100" role="presentation">
#           <tbody>
#            <tr role="presentation">
#             <td class="UHCol1" role="presentation">
#              <h1 style="margin: 0;">
#               <a class="y-logo D-b Pstart-6" data-ylk="subsec:logo;slk:logo;" href="/">
#                <img alt="Yahoo奇摩首頁" height="50" src="https://s1.yimg.com/rz/d/yahoo_frontpage_zh-Hant-TW_s_f_p_bestfit_frontpage_2x.png"/>
#               </a>
#              </h1>
#              <a class="logo-hpset C-w Cur-p Fz-xs Px-4 Py-2 Mt-2 D-ib TW" data-ylk="rspns:nav;t1:a3;t2:uh;t3:ct;sec:uh;subsec:hpset;slk:hpset;elm:btn;elmt:ct;itc:1;" href="https://tw.help.yahoo.com/kb/SLN2208.html" target="_blank">
#               設為首頁
#              </a>
#             </td>
#             <td class="Pb-0" role="presentation">
#              <style>
#               #Stencil body {
#   margin-top: 125px !important;
# }
#              </style>
#              <form action="https://tw.search.yahoo.com/search" class="Pos-r" id="UHSearch" method="get" role="search">
#               <table class="W-100 M-0" role="presentation">
#                <tbody>
#                 <tr role="presentation">
#                  <td class="W-100" id="UHSearchBoxContainer" role="presentation">
#                   <div class="Pos-r" id="UHSearchBoxWrapper">
#                    <input id="fr" name="fr" type="hidden" value="yfp-search-sb"/>
amp;fr=yfp-search-tn&amp;fr2=fp-hotsearch">
#                      衣物收納箱
#                     </a>
#                    </li>
#                    <li class="D-i Fl-start keyword ">
#                     <a class="Pend-16 Whs-nw" data-ylk="elm:itm;tts:1;tts-term:劉泰英周旋4女;tts-pos:8;tts-cat:%7B%22yct%3A001000069%22%3A3%7D;" href="https://tw.search.yahoo.com/search?p=%E5%8A%89%E6%B3%B0%E8%8B%B1%E5%91%A8%E6%97%8B4%E5%A5%B3&amp;fr=yfp-search-tn&amp;fr2=fp-hotsearch">
#                      劉泰英周旋4女
#                     </a>
#                    </li>
#                    <li class="D-i Fl-start keyword ">
#                     <a class="Pend-16 Whs-nw" data-ylk="elm:itm;tts:1;tts-term:日本地下神殿;tts-pos:9;tts-cat:%7B%22yct%3A001000655%22%3A2%2C%22yct%3A001000638%22%3A1%2C%22yct%3A001000637%22%3A3%7D;" href="https://tw.search.yahoo.com/search?p=%E6%97%A5%E6%9C%AC%E5%9C%B0%E4%B8%8B%E7%A5%9E%E6%AE%BF&amp;fr=yfp-search-tn&amp;fr2=fp-hotsearch">
#                      日本地下神殿
#                     </a>
#                    </li>
#                    <li class="D-i Fl-start keyword ">
#                     <a class="Pend-16 Whs-nw" data-ylk="elm:itm;tts:1;tts-term:台積電法說會;tts-pos:10;tts-cat:%7B%22yct%3A001000345%22%3A1%2C%22yct%3A001000327%22%3A2%2C%22yct%3A001000323%22%3A2%2C%22yct%3A001000351%22%3A1%2C%22yct%3A001000298%22%3A2%7D;" href="https://tw.search.yahoo.com/search?p=%E5%8F%B0%E7%A9%8D%E9%9B%BB%E6%B3%95%E8%AA%AA%E6%9C%83&amp;fr=yfp-search-tn&amp;fr2=fp-hotsearch">
#                      台積電法說會
#                     </a>
#                    </li>
#                    <li class="D-i Fl-start keyword ">
#                     <a class="Pend-16 Whs-nw" data-ylk="elm:itm;tts:1;tts-term:亞錦賽賽程表;tts-pos:11;tts-cat:%7B%7D;" href="https://tw.search.yahoo.com/search?p=%E4%BA%9E%E9%8C%A6%E8%B3%BD%E8%B3%BD%E7%A8%8B%E8%A1%A8&amp;fr=yfp-search-tn&amp;fr2=fp-hotsearch">
#                      亞錦賽賽程表
#                     </a>
#                    </li>
#                   </ul>
#                  </td>
#                 </tr>
#                </tbody>
#               </table>
#              </form>
#             </td>
#             <td class="UHCol3" role="presentation">
#              <span class="Abu-Pc-Icon Fz-xl Mx-4 My-6 D-n" id="pphw-triggerbtn">
#              </span>
#              <ul class="Ta-end Mx-10 Grid Whs-nw Mt-10 Tabbar-List">
#               <li class="tabbar-weather Ta-j tabbar Grid-U Pos-r Pend-18" data-plugin="tooltip" data-tooltip='{"target-parent":".Weather-Simple-Image","mouseenter":{"show":{"classes": "FancyBox Arrow Pos-a Lh-14 Z-5 Mt-10 Tooltip", "mouseover":true,"position":"bl","id":"yucs-weather-panel"}},"mouseleave":{"hide":{"id":"yucs-weather-panel"}}}' data-trigger="mouseenter mouseleave click" style="">
#                <div data-region="td-applet-abu">
#                 <style>
# ...
#                 },
#                 inlineViewer: 0,
#                 summaryView: 0,
#                 stickerTarget: null,
#                 magazineViewerEnabled: 1,
#                 viewerBlacklistDisable: 0,
#                 viewer: {
#                     highlanderMode: "",
#                     offnetDeeplink: 0,
#                     offnetFauxdal: 0,
#                     pageAnimation: "zoom",
#                     scrollTopAmount: 0,
#                     viewerAnimation: "slide",
#                     enableVerticalVideo: 0
#                 }}
#             );
#             YMedia.My.App.on('appletdeferload', function(evt){
#                 if (evt && evt.applet && evt.applet.type.indexOf('wafer') >= 0) {
#                     window && window.wafer && window.wafer.base._sync();
#                 }
#             });
#
#
#
#         });
#                 });
#      });
#   </script>
#   <!-- Comscore -->
#   <!-- Begin comScore Tag -->
#   <script>
#    var _comscore = _comscore || [];
#             window.__cmp('getVendorConsents', null, function(result, success) {
#                  		  var comsCoreParams = {
# 		    c1: "2",
# 		    c2: "7241469",
# 		    c5: "152963594",
# 		    c7: "https://tw.yahoo.com/",c14: "-1"
# 		  };
#                   var result = result || {};
#                   if (typeof success === "boolean" && success && result.gdprApplies && result.vendorConsents) {
#                       var COMSCORE_VENDOR_ID = 77;
#                       comsCoreParams.cs_ucfr = result.vendorConsents[COMSCORE_VENDOR_ID] ? 1 : 0;
#                   }
# 		  _comscore.push(comsCoreParams);
# 		  (function() {
# 		    var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# 		    s.src = "https://s.yimg.com/lq/lib/3pm/cs_0.2.js";
# 		    el.parentNode.insertBefore(s, el);
# 		  })();
#             });
#   </script>
#   <noscript>
#    <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=7241469&amp;c7=https%3A%2F%2Ftw.yahoo.com%2F&amp;c5=152963594&amp;cv=2.0&amp;cj=1&amp;c14=-1">
#    </img>
#   </noscript>
#   <!-- End comScore Tag -->
#   <!-- Nielsen -->
#   <!-- eStat -->
#   <!-- yaft -->
#   <script defer="" src="https://s.yimg.com/os/yaft/yaft-0.3.27.min.js" type="text/javascript">
#   </script>
#   <script defer="" src="https://s.yimg.com/os/yaft/yaft-plugin-aftnoad-0.1.5.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function yaftPreProcess() {
#                 // collect ad load times call YAFT.triggerCustomTiming right before the AFT calculation finished
#                 var darlaAdTimings = [];
#                 var adTiming;
#                 var whiteListedAds = {"LREC":"my-adsLREC-base","MAST":"my-adsMAST","LDRB":"my-adsLDRB","UBALDRB":"my-adsUBALDRB","TL1":"my-adsTL1","TXTL":"my-adsTXTL","LREC-0":"hl-ad-LREC-0","MON-0":"hl-ad-MON-0","MAST-0":"hl-ad-MAST-0","LDRB-0":"hl-ad-LDRB-0","SPL2-0":"hl-ad-SPL2-0","SPL-0":"hl-ad-SPL-0","LDRB-1":"viewer-LDRB","MON-1":"viewer-MON","LREC-1":"viewer-LREC","LREC-2":"viewer-LREC2"};
#                 var w = window;
#                 var aft2StartRender = w.YAFT.AFT2.getAFT2StartRender() - 800;
#                 if (typeof w._adLT !== 'undefined' && w.performance && w.performance.now) {
#                     for (var i = 0; i < w._adLT.length; i++) {
#                         adTiming = w._adLT[i];
#                         var adIdAction = adTiming[0];
#                         var adTime = adTiming[1];
#                         var adAction = adIdAction.indexOf('ADSTART_') > -1 ? 'start' : 'end';
#                         var adId = '';
#
#                         if (adAction === 'start') {
#                             adId = adIdAction.replace('ADSTART_', '');
#                             darlaAdTimings[adId] = {
#                                 started: adTime,
#                                 loaded: 0
#                             };
#                         } else {
#                             adId = adIdAction.replace('ADEND_', '');
#                             if (typeof darlaAdTimings[adId] !== 'undefined') {
#                                 darlaAdTimings[adId].loaded = adTime;
#                             }
#                         }
#                     }
#
#                     for (var adObj in darlaAdTimings) {
#                         if (darlaAdTimings.hasOwnProperty(adObj) && typeof whiteListedAds[adObj] !== undefined) {
#                             var adStartTime = darlaAdTimings[adObj].started;
#                             var adLoadTime = darlaAdTimings[adObj].loaded || w.performance.now();
#                             if (aft2StartRender > adStartTime) {continue;}
#                             w.YAFT.triggerCustomTiming(whiteListedAds[adObj], adStartTime, adLoadTime);
#                         }
#                     }
#                 }
#
#                 // calculate custom video timing
#                 if (typeof w._videoLT !== 'undefined' && w.YAFT && w.YAFT.isInitialized() && w.performance && typeof w.performance.now === 'function') {
#                     Object.getOwnPropertyNames(window._videoLT).forEach(function(key) {
#                         w.YAFT.triggerCustomTiming(key, window._videoLT[key].startTime, window._videoLT[key].loadTime || w.performance.now());
#                     });
#                 }
#             }
#
#             function yaftInit(e) {
#                 if (window.YAFT !== undefined) {
#                     var __yaftConfig = {
#                         modules: ["applet_p_40769040","UH","applet_p_1468442","applet_p_50000183","my-adsFPL","my-adsFPAD","my-adsFPR","my-adsFPT"],
#                         modulesExclude: ["my-adsMAST-base"],
#                         canShowVisualReport: false,
#                         useNormalizeCoverage: true,
#                         includeOnlyAft2: false,
#                         useNativeStartRender : true,
#                         useNativeStartRenderMeaningful : true,
#                         customReportModules: [],
#
#                         maxWaitTime: 6000,
#                         preProcess: yaftPreProcess,
#                         preferDataModNameOverId: false
#                     };
#                     __yaftConfig.plugins = [];
#
#
#                     window.YAFT.init(__yaftConfig, function(data, error) {
#                         var i;
#                         if (!error) {
#                             try {
#                                         var rapidInstance = YAHOO.i13n.rapidInstance ? YAHOO.i13n.rapidInstance : (YMedia.My && YMedia.My.App && YMedia.My.App.getRapidTracker) ? YMedia.My.App.getRapidTracker() : null;
#         if(rapidInstance) {
#             var initialPageLoad = {
#                 AFT: Math.round(data.aft),
#                 AFT1: Math.round(data.aft),
#                 STR: Math.round(data.startRender),
#                 VIC: data.visuallyComplete,
#                 PLT: data.pageLoadTime,
#                 DOMC: data.domElementsCount,
#                 HTTPC: data.httpRequests.count,
#                 CP: Math.round(data.totalCoveragePercentage),
#                 NCP: Math.round(data.normTotalCoveragePercentage)
#             };
#
#             if(data.aftNoAd) {
#                 initialPageLoad.AFTNOAD = Math.round(data.aftNoAd);
#             }
#
#             var customPerfData = {},
#                 pagePerfData = {},
#                 results = [];
#
#             var yaftResults = [0], yaftModule = '', yaftIndex = '';
#             // Find costly resource time
#             for (yaftModule in data.modulesReport) {
#                 for (yaftIndex in data.modulesReport[yaftModule].resources) {
#                     yaftResults.push(Math.round(data.modulesReport[yaftModule].resources[yaftIndex].durationFromNStart));
#                 }
#             }
#             pagePerfData['COSTLY_RESOURCE'] = Math.max.apply(null, yaftResults);
#             pagePerfData['X_FB1'] = 15;
#             pagePerfData['X_FBN'] = 47;
#
#             // Log ad perf data to rapid perf metric
#             if (window.FPAD_rendered) {
#                 pagePerfData['xAFT'] = data.aft;
#                 pagePerfData['xPLT'] = data.pageLoadTime;
#                 if (window.rtFpadAdStart) {
#                     pagePerfData['ADSTART_FPAD'] = Math.round(window.rtFpadAdStart);
#                     if (window.rtAdStart) {
#                          pagePerfData['ADCSTART_FPAD'] = Math.round(window.rtAdStart);
#                     }
#                     var adEndTime = window.rtAdDone ? window.rtAdDone : (window.performance && window.performance.now && window.performance.now());
#                     pagePerfData['ADEND_FPAD'] = Math.round(adEndTime);
#                 }
#             }
#
#             // Track ad metrics
#             if ( window._adLT) {
#                 for (var i = 0; i< _adLT.length; i++) {
#                     pagePerfData[_adLT[i][0]]  = _adLT[i][1];
#                 }
#             }
#
#             // Track video metrics
#             if (window._videoLT) {
#                 Object.getOwnPropertyNames(window._videoLT).forEach(function(key, index) {
#                     var videoStartKey = 'VIDEO_' + (index + 1) + '_START';
#                     var videoEndKey = 'VIDEO_' + (index + 1) + '_END';
#                     pagePerfData[videoStartKey] = Math.round(window._videoLT[key].startTime);
#                     pagePerfData[videoEndKey] = Math.round(window._videoLT[key].loadTime || 99999);
#                 });
#             }
#
#
#             // Track user connection type
#             var navConnection = navigator && (navigator.connection || navigator.mozConnection || navigator.webkitConnection) || {};
#             pagePerfData['CONNECTION_TYPE'] = navConnection.effectiveType || 'unknown';
#
#             customPerfData['utm'] = pagePerfData;
#             var perfData = {
#                 perf_commontime: {initialPageLoad: initialPageLoad},
#                 perf_usertime: customPerfData
#             };
#             rapidInstance.beaconPerformanceData(perfData);
#         }
#                             } catch (e) {}
#                         }
#                    });
#                 }
#             }
#             if (window.addEventListener) {
#                 window.addEventListener('DOMContentLoaded', yaftInit, false);
#                 var _yaftScrollingTimer,
#     _yaftIsScrolling = false,
#     _yaftIsDone = false,
#     _yaftMaxScroll = 5,
#     _yaftScrollingTimerDelay = 66,
#     _yaftScrollCounter = 1,
#     YMedia = YMedia || null,
#     rapidInstance = (YAHOO && YAHOO.i13n && YAHOO.i13n.rapidInstance) || (YMedia && YMedia.My && YMedia.My.App && YMedia.My.App.getRapidTracker && YMedia.My.App.getRapidTracker()) || null;
#
# // Listen for scroll events
# window.addEventListener('scroll', function ( event ) {
#     if (_yaftScrollCounter > _yaftMaxScroll) {
#         return;
#     }
#     if (!_yaftIsScrolling) {
#         window.YAFT.FPS.start('FPSIndex');
#         _yaftIsScrolling = true;
#     }
#     // Clear our timeout throughout the scroll
#     window.clearTimeout(_yaftScrollingTimer);
#
#     // Set a timeout to run after scrolling ends
#     _yaftScrollingTimer = setTimeout(function() {
#         _yaftIsScrolling = false;
#         window.YAFT.FPS.stop('FPSIndex', function(err, data) {
#             var payload;
#             if (!err) {
#                 payload = {
#                    utm: {
#                        fps_average_index: Math.round(data.avgFps),
#                        fps_lowest_index: Math.round(data.worse)
#                    }
#                 };
#                 _yaftScrollCounter++;
#                 if (rapidInstance) {
#                     rapidInstance.beaconPerformanceData({perf_usertime: payload});
#                 }
#             }
#         });
#     }, _yaftScrollingTimerDelay);
#
# }, false);
#             } else if (window.attachEvent) {
#                 window.attachEvent('DOMContentLoaded', yaftInit);
#             }
#   </script>
#   <!-- dad Tracking -->
#   <script type="text/javascript">
#    function _daTRK() {
#     var daTrk = '-1';
#     var daFr = 0;
#     var cExpiry = 0;
#         if (window.pageloadNonCollapsedAds && window.pageloadNonCollapsedAds.length > 0) {
#         daTrk = '0';
#         for (i=0; i<window.pageloadNonCollapsedAds.length; i++) {
#             var daTRKDiv = document.getElementById("my-ads" + pageloadNonCollapsedAds[i]);
#             if (daTRKDiv && daTRKDiv.offsetHeight === 0) {
#                 daTrk = '1';
#                 cExpiry = 10080;
#                 break;
#             }
#         }
#     } else {
#         var daTRKDiv = document.getElementById("my-adsFPAD");
#         if (daTRKDiv ) {
#             daTrk = '0';
#             if (daTRKDiv.offsetHeight === 0) {
#                 cExpiry = 10080;
#                     daTrk = '1';
#                 }
#             }
#         }
#     if (daFr || '1' === daTrk) {
#         window.thamba = 1;
#     }
#
#     YUI().use('cookie', function(Y) {
#
#         function fireThambaEvent() {
#             Y.use('event', function(YM) {
#                 if(YM.Cookie.exists('thamba')) {
#                     var clientSideVal = parseInt(YM.Cookie.get('thamba'), 10);
#                     var serverSideVal = 0;
#                     if(window.rapidPageConfig &&
#                         window.rapidPageConfig.rapidConfig &&
#                         window.rapidPageConfig.rapidConfig.keys &&
#                         window.rapidPageConfig.rapidConfig.keys.abk) {
#                         var value = window.rapidPageConfig.rapidConfig.keys.abk;
#
#                         switch(value) {
#                             case 'abp':
#                                 serverSideVal = 2;
#                                 break;
#                             case 'other':
#                                 serverSideVal = 1;
#                                 break;
#                         }
#                     }
#
#                     if(0 === serverSideVal && clientSideVal > serverSideVal) {
#                         YM.Global.fire('thamba:value-change', {"clientVal": clientSideVal, "serverVal": serverSideVal});
#                     }
#                 }
#             });
#         }
#
#         var expires = new Date();
#         expires.setMinutes(expires.getMinutes() + cExpiry);
#         Y.Cookie.set('thamba', daTrk, {expires: expires, domain: location.hostname});
#         if (typeof window.thamba != 'undefined') {
#                     var DPba=new function(){this.detect=function(px,callback){var detected=false;var checksRemain=2;var error1=false;var error2=false;if(typeof callback!="function")return;px+="?ch=*&rn=*";function beforeCheck(callback,timeout){if(checksRemain==0|| timeout>1E3)callback(checksRemain==0&&detected);else setTimeout(function(){beforeCheck(callback,timeout*2)},timeout*2)}function checkImages(){if(--checksRemain)return;detected=!error1&&error2}var random=Math.random()*11;var img1=new Image;img1.onload=checkImages;img1.onerror=function(){error1=true;checkImages()};img1.src=px.replace(/\*/,1).replace(/\*/,random);var img2=new Image;img2.onload=checkImages;img2.onerror=function(){error2=true;checkImages()};img2.src=px.replace(/\*/,2).replace(/\*/,random);beforeCheck(callback,250)}};
#         DPba.detect("/px.gif", function(usesABP) {
#             if (usesABP) {
#                 var expires = new Date();
#                 expires.setMinutes(expires.getMinutes() + 10080);
#                 Y.Cookie.set('thamba', '2', {expires: expires, domain: location.hostname});
#                 fireThambaEvent();
#             }
#         });
#         } else {
#             fireThambaEvent();
#         }
#     });
# }
#
# YUI().use('node','event-base', function (Y) {
#     Y.on ('domready', function () {
#         setTimeout(function() {window._daTRK()}, 300);
#     });
# });
#   </script>
#   <!-- Adobe Tracking -->
#   <!-- Via https/1.1 media-router-fp1010.prod.media.tp2.yahoo.com[734dae29-b44b-491c-bc0c-e053bc0f9af7] (YahooTrafficServer), http/1.1 media-router-omega41.prod.media.tp2.yahoo.com[ff0881bb-1e9f-4b63-930e-0e8902fe8766] (YahooTrafficServer) -->
#   <!-- sid=152963594 -->
#  </body>
# </html>
# <!-- arcade--production-tp2-64b64d9d8-l8d4s Wed Oct 16 07:06:31 UTC 2019 -->
